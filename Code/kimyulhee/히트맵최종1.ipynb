# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 데이터 로드 및 날짜 열을 datetime 형식으로 변환
data = pd.read_csv('../../Data/기상청/합체한따릉이.csv', encoding='cp949')
data['기준_날짜'] = pd.to_datetime(data['기준_날짜'])

# 결측치 제거
data = data.dropna()

# 필요한 데이터만 선택하고 상관계수 계산
corr_matrix = data[['평균기온(°C)', '일강수량(mm)', '전체_건수']].corr()

# 히트맵 그리기
fig, ax = plt.subplots(figsize=(10, 8))  # 플롯 크기 설정
cax = ax.matshow(corr_matrix, cmap='coolwarm')  # 상관계수 매트릭스에 히트맵 적용
fig.colorbar(cax)  # 컬러바 추가

# 축 설정
ax.set_xticks(np.arange(len(corr_matrix.columns)))
ax.set_yticks(np.arange(len(corr_matrix.index)))
ax.set_xticklabels(corr_matrix.columns)
ax.set_yticklabels(corr_matrix.index)

# 각 셀에 상관계수 값 추가
for (i, j), val in np.ndenumerate(corr_matrix):
    ax.text(j, i, f'{val:.2f}', ha='center', va='center', color='white')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 13
#      10 data = data.dropna()
#      12 # 필요한 데이터만 선택하고 상관계수 계산
# ---> 13 corr_matrix = data[['평균기온(°C)', '일강수량(mm)' '전체_건수']].corr()
#      15 # 히트맵 그리기
#      16 fig, ax = plt.subplots(figsize=(10, 8))  # 플롯 크기 설정
#
# File c:\Users\ciw96\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\ciw96\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
# ...

# %%
len(data)
# Out:
# 367

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
fm.findSystemFonts(fontpaths=None, fontext='ttf')
path = 'C:\\Windows\\Fonts\\malgunbd.ttf'  
fontprop = fm.FontProperties(fname=path, size=12)

# Matplotlib의 기본 폰트 설정 변경
plt.rc('font', family=fontprop.get_name())

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 데이터 로드 및 날짜 열을 datetime 형식으로 변환
data = pd.read_csv('../../Data/기상청/합체한따릉이.csv', encoding='cp949')
data['기준_날짜'] = pd.to_datetime(data['기준_날짜'])

# 결측치 제거
data = data.dropna()

# 필요한 데이터만 선택
selected_data = data[['평균기온(°C)', '일강수량(mm)', '미세먼지', '전체_건수']]

# 상관계수 계산
corr_with_total_counts = selected_data.corr()['전체_건수'].to_frame()

# 히트맵 그리기
plt.figure(figsize=(6, 8))
sns.heatmap(corr_with_total_counts, annot=True, cmap='coolwarm', fmt=".2f", cbar=False)
plt.title('Correlation Heatmap with Total Counts')
plt.show()
# Out:
# c:\Users\ciw96\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   fig.canvas.draw()
# c:\Users\ciw96\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 52404 (\N{HANGUL SYLLABLE CE}) missing from current font.
#   fig.canvas.draw()
# c:\Users\ciw96\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 44148 (\N{HANGUL SYLLABLE GEON}) missing from current font.
#   fig.canvas.draw()
# c:\Users\ciw96\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.draw()
# c:\Users\ciw96\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from current font.
#   fig.canvas.draw()
# ...

# %%
data
# Out:
#          기준_날짜   미세먼지  초미세먼지     지점 지점명  평균기온(°C)  일강수량(mm)
# 3   2023-04-04   38.0   18.0  108.0  서울      17.6       6.9
# 4   2023-04-05   20.0   10.0  108.0  서울      11.9      50.3
# 5   2023-04-06   73.0   55.0  108.0  서울       8.8       2.7
# 10  2023-04-11   79.0   17.0  108.0  서울      13.1       2.9
# 12  2023-04-13  217.0   24.0  108.0  서울      11.9       0.0
# ..         ...    ...    ...    ...  ..       ...       ...
# 358 2024-03-23   62.0   23.0  108.0  서울      13.0       0.1
# 360 2024-03-25   25.0    9.0  108.0  서울      10.6       5.1
# 361 2024-03-26    4.0    1.0  108.0  서울       7.4      11.5
# 363 2024-03-28   25.0   11.0  108.0  서울      10.3       1.9
# 364 2024-03-29  277.0   43.0  108.0  서울       7.6       1.4
#
# [164 rows x 7 columns]

# %%
미세먼지 = pd.read_csv('../../Data/기상청/4-3미세먼지.csv', encoding='cp949')

따릉이_0401 = pd.read_csv('../choiinwoo/tpss_bcycl_od_statnhm_20240401.csv', encoding='cp949')
미세먼지.head()
강수량 = pd.read_csv('../../Data/기상청/강수량.csv', encoding='utf-8')
기상청 = pd.read_csv('../../Data/기상청/기온강수량미세먼지2.csv', encoding='cp949')
출퇴근_이용량_통합 = pd.read_csv('../../Data/따릉이/출퇴근_이용량_통합.csv', encoding='utf-8')
마스터따릉이정보 = pd.read_csv('../../Data/따릉이/서울시 따릉이대여소 마스터 정보.csv', encoding='cp949')
기온 = pd.read_csv('../../Data/기상청/기온.csv', encoding='cp949')
쏠림정도_top20_대여소 = pd.read_csv('../../Data/따릉이/쏠림정도_top20_대여소.csv', encoding='utf-8')

# %%
마스터따릉이정보.head()
# Out:
#    대여소_ID                      주소1            주소2         위도          경도
# 0  ST-999       서울특별시 양천구 목동서로 280  목동아파트 8단지 상가동   0.000000    0.000000
# 1  ST-998       서울특별시 양천구 목동서로 130  목동아파트 4단지 상가동   0.000000    0.000000
# 2  ST-997       서울특별시 양천구 목동중앙로 49  목동3단지 시내버스정류장  37.534390  126.869598
# 3  ST-996   서울특별시 양천구 남부순환로88길5-16     양강중학교앞 교차로  37.524334  126.850548
# 4  ST-995  서울특별시 양천구 중앙로 153 공중화장실            NaN  37.510597  126.857323

# %%
미세먼지.head()

# %% [markdown]
# 기상청.head()

# %%
출퇴근_이용량_통합.head()
# Out:
#    Unnamed: 0   대여소_ID  출근대여량  출근반납량  대여-반납량_출근  차이절대값_출근  총이용량_출근  퇴근대여량  \
# 0           0  ST-1062   3743   2281       1462      1462     6024   3947
# 1           1  ST-1063   5029   8839      -3810      3810    13868   5795
# 2           2  ST-1064   3764   8489      -4725      4725    12253   9005
# 3           3  ST-1065   5860   5507        353       353    11367  14431
# 4           4  ST-1067   3394   2906        488       488     6300   2666
#
#    퇴근반납량  대여-반납량_퇴근  차이절대값_퇴근  총이용량_퇴근  출퇴근_총이용량 최종용도
# 0   5456      -1509      1509     9403     15427   주거
# 1   3170       2625      2625     8965     22833   상업
# 2   5562       3443      3443    14567     26820   상업
# 3  16569      -2138      2138    31000     42367   주거
# 4   3654       -988       988     6320     12620   주거

# %%
쏠림정도_top20_대여소.head()
# Out:
#    Unnamed: 0 최종용도   대여소_ID  temp_num  출근대여량  출근반납량  대여-반납량_출근  차이절대값_출근  \
# 0           0   상업  ST-1064       180   3764   8489      -4725      4725
# 1           1   상업  ST-1688       188    881   7017      -6136      6136
# 2           2   상업  ST-1712       193    698  11208     -10510     10510
# 3           3   상업  ST-2031       182  18661  22323      -3662      3662
# 4           4   상업  ST-2033       195    927  17721     -16794     16794
#
#    총이용량_출근  퇴근대여량  퇴근반납량  대여-반납량_퇴근  차이절대값_퇴근  총이용량_퇴근  출퇴근_총이용량  차이절대값합
# 0    12253   9005   5562       3443      3443    14567     26820    8168
# 1     7898   7922   3320       4602      4602    11242     19140   10738
# 2    11906   7548    754       6794      6794     8302     20208   17304
# 3    40984  27533  22552       4981      4981    50085     91069    8643
# 4    18648  14171   3574      10597     10597    17745     36393   27391

# %%
기상청.head()
# Out:
#         기준_날짜   미세먼지  초미세먼지     지점 지점명  평균기온(°C)  일강수량(mm)
# 0  2023-04-01  111.0   56.0  108.0  서울      17.5       NaN
# 1  2023-04-02   60.0   32.0  108.0  서울      18.8       NaN
# 2  2023-04-03   58.0   32.0  108.0  서울      19.0       NaN
# 3  2023-04-04   38.0   18.0  108.0  서울      17.6       6.9
# 4  2023-04-05   20.0   10.0  108.0  서울      11.9      50.3

# %%
강수량.head()
# Out:
#     지점 지점명          일시  일강수량(mm)
# 0  108  서울  2023-04-04       6.9
# 1  108  서울  2023-04-05      50.3
# 2  108  서울  2023-04-06       2.7
# 3  108  서울  2023-04-11       2.9
# 4  108  서울  2023-04-13       0.0

# %%
기온.head()
# Out:
#     지점 지점명          일시  평균기온(°C)  최저기온(°C)  최고기온(°C)
# 0  108  서울  2023-04-01      17.5       9.4      25.6
# 1  108  서울  2023-04-02      18.8      11.9      25.2
# 2  108  서울  2023-04-03      19.0      11.3      25.9
# 3  108  서울  2023-04-04      17.6      12.7      21.7
# 4  108  서울  2023-04-05      11.9       8.7      14.9

# %%
따릉이_0401.head()
# Out:
#       기준_날짜 집계_기준  기준_시간대 시작_대여소_ID     시작_대여소명 종료_대여소_ID      종료_대여소명  전체_건수  \
# 0  20240401  출발시간       0   ST-1002   목1동_004_1   ST-1323    도림동_027_1      1
# 1  20240401  출발시간       0   ST-1002   목1동_004_1   ST-2559   신도림동_072_1      1
# 2  20240401  출발시간       0   ST-1017   목5동_059_1   ST-2773    목5동_063_1      1
# 3  20240401  출발시간       0   ST-1034   증산동_038_1    ST-345  북가좌1동_025_1      1
# 4  20240401  출발시간       0   ST-1061  천호1동_039_1   ST-2750     길동_008_1      1
#
#    전체_이용_분  전체_이용_거리
# 0       18      3469
# 1       23      3086
# 2        3       457
# 3        5       920
# 4       12       577

# %%
강서_대여소_ID = pd.read_csv('../../Data/따릉이/강서_따릉이_대여소_ID.csv',encoding='utf-8')

강서_데이터1 = pd.read_csv('../../Data/따릉이/강서_따릉이_데이터_01.csv',encoding='utf-8')
강서_데이터2 = pd.read_csv('../../Data/따릉이/강서_따릉이_데이터_02.csv',encoding='utf-8')

강서_데이터 = pd.concat([강서_데이터1, 강서_데이터2], ignore_index=True)


top_20_ID = pd.read_csv('../../Data/따릉이/쏠림정도_top20_대여소.csv',encoding='utf-8')
# 주거와 상업으로 데이터 분할
주거_df = top_20_ID[top_20_ID['최종용도'] == '주거']
상업_df = top_20_ID[top_20_ID['최종용도'] == '상업']

# 주거 데이터에서 대여소_ID 추출
주거_IDs = 주거_df['대여소_ID'].unique()

# 상업 데이터에서 대여소_ID 추출
상업_IDs = 상업_df['대여소_ID'].unique()

강서_df = 강서_데이터[강서_데이터['시작_대여소_ID'].isin(주거_IDs)] # 시작 : 대여 ,종료 : 반납   + 주거, 상업
강서_df = 강서_df.sort_values(by='기준_날짜')

강서_df['시간대_구간'] = 강서_df['기준_시간대'].apply(divide_time_range)
강서_df1 = 강서_df[강서_df['시간대_구간'] == '06:00~10:00']     # 06~10 : , 17:21 :퇴근
강서_df1 = 강서_df1[(강서_df1['전체_이용_분'] != 0) & (강서_df1['전체_이용_거리'] != 0)]

강서_df1 = 강서_df1[['시작_대여소_ID', '기준_날짜', '전체_건수']].copy() # 시작 : 대여 ,종료 : 반납
강서_df1 = 강서_df1.rename(columns={'시작_대여소_ID': '대여소_ID'})     # 시작 : 대여 ,종료 : 반납

# ADF 테스트 수행
adf_result = adfuller(강서_df1[강서_df1['대여소_ID']=='ST-2056']['전체_건수'])


# ADF 통계량 및 p-value 출력
print(f'ADF 통계량: {adf_result[0]}')
print(f'p-value: {adf_result[1]}')

# 결과 해석
if adf_result[1] < 0.05:
    print('p-value가 유의수준보다 작으므로 귀무가설을 기각합니다. 시계열 데이터는 정상성을 만족합니다.')
else:
    print('p-value가 유의수준보다 크거나 같으므로 귀무가설을 기각할 수 없습니다. 시계열 데이터는 정상성을 만족하지 않을 수 있습니다.')
# Out:
# ADF 통계량: -53.363088295105
# p-value: 0.0
# p-value가 유의수준보다 작으므로 귀무가설을 기각합니다. 시계열 데이터는 정상성을 만족합니다.

# %%
기상청.head()
# Out:
#         기준_날짜   미세먼지  초미세먼지     지점 지점명  평균기온(°C)  일강수량(mm)
# 0  2023-04-01  111.0   56.0  108.0  서울      17.5       NaN
# 1  2023-04-02   60.0   32.0  108.0  서울      18.8       NaN
# 2  2023-04-03   58.0   32.0  108.0  서울      19.0       NaN
# 3  2023-04-04   38.0   18.0  108.0  서울      17.6       6.9
# 4  2023-04-05   20.0   10.0  108.0  서울      11.9      50.3
