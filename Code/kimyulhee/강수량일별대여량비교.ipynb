# %%
import pandas as pd
import matplotlib.pyplot as plt

# CSV 파일 로드
rentals = pd.read_csv('일별따릉이대여량2.csv')  # 대여량 데이터 포함
temperature = pd.read_csv('기온강수량미세먼지2.csv', encoding='cp949')  # 기온 데이터 포함

# 날짜 형식이 같은지 확인하고 필요하면 통일시키기
rentals['기준_날짜'] = pd.to_datetime(rentals['기준_날짜'])
temperature['기준_날짜'] = pd.to_datetime(temperature['기준_날짜'])

# 데이터 병합
data = pd.merge(rentals, temperature, on='기준_날짜', how='inner')

# %%
# 대여량과 기온 간의 상관관계 계산
correlation = data['전체_건수'].corr(data['평균기온(°C)'])
print("상관계수:", correlation)

# 상관계수 시각화
plt.figure(figsize=(6, 4))
plt.bar(['Correlation'], [correlation], color='blue')
plt.ylim(0, 1)  # 상관계수 범위는 -1에서 1까지이나 예시로 0에서 1 범위 설정
plt.ylabel('Correlation Coefficient')
plt.title('Correlation between Rental Count and Temperature')
plt.show()
# Out:
# 상관계수: 0.5825297382807604

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# CSV 파일 로드
rainfall = pd.read_csv('기온강수량미세먼지2.csv', encoding= 'cp949')  # 일별 강수량 데이터 포함
rentals = pd.read_csv('일별따릉이.csv')  # 일별 대여량 데이터 포함

# 날짜 형식 통일 및 데이터 병합
rainfall['기준_날짜'] = pd.to_datetime(rainfall['기준_날짜'])
rentals['기준_날짜'] = pd.to_datetime(rentals['기준_날짜'])
data = pd.merge(rainfall, rentals, on='기준_날짜', how='inner')

# %%
# 상관관계 계산
correlation = data['일강수량(mm)'].corr(data['전체_건수'])
print("상관계수:", correlation)

# 상관관계 시각화
plt.figure(figsize=(10, 6))
sns.scatterplot(x='일강수량(mm)', y='전체_건수', data=data)
sns.regplot(x='일강수량(mm)', y='전체_건수', data=data, scatter=False, color='red')
plt.title('Scatter plot of Daily Rainfall vs. Rental Count with Regression Line')
plt.xlabel('Daily Rainfall (mm)')
plt.ylabel('Daily Rental Count')
plt.grid(True)
plt.show()
# Out:
# 상관계수: -0.2564515427051864

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# CSV 파일 로드
rainfall = pd.read_csv('기온강수량미세먼지2.csv', encoding= 'cp949')  # 일별 강수량 데이터 포함
rentals = pd.read_csv('일별따릉이.csv')  # 일별 대여량 데이터 포함

# 날짜 형식 통일 및 데이터 병합
rainfall['기준_날짜'] = pd.to_datetime(rainfall['기준_날짜'])
rentals['기준_날짜'] = pd.to_datetime(rentals['기준_날짜'])
data = pd.merge(rainfall, rentals, on='기준_날짜', how='inner')

# %%
# 상관관계 계산
correlation = data['평균기온(°C)'].corr(data['전체_건수'])
print("상관계수:", correlation)

# 상관관계 시각화
plt.figure(figsize=(10, 6))
sns.scatterplot(x='평균기온(°C)', y='전체_건수', data=data)
sns.regplot(x='평균기온(°C)', y='전체_건수', data=data, scatter=False, color='red')
plt.title('Scatter plot of Daily Rainfall vs. Rental Count with Regression Line')
plt.xlabel('Daily Rainfall (mm)')
plt.ylabel('Daily Rental Count')
plt.grid(True)
plt.show()
# Out:
# 상관계수: 0.3100369581436954

# %%
# 상관관계 계산
correlation = data['미세먼지'].corr(data['전체_건수'])
print("상관계수:", correlation)

# 상관관계 시각화
plt.figure(figsize=(10, 6))
sns.scatterplot(x='미세먼지', y='전체_건수', data=data)
sns.regplot(x='미세먼지', y='전체_건수', data=data, scatter=False, color='red')
plt.title('Scatter plot of Daily Rainfall vs. Rental Count with Regression Line')
plt.xlabel('Daily Rainfall (mm)')
plt.ylabel('Daily Rental Count')
plt.grid(True)
plt.show()
# Out:
# 상관계수: 0.0582771561236704

# %%
# 박스플롯 그리기
plt.figure(figsize=(12, 6))
plt.boxplot([data['평균기온(°C)'], data['전체_건수']], labels=['temperature', 'count'])
plt.title('Box Plot of Daily Rainfall and Rental Count')
plt.ylabel('Value')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.boxplot([data['일강수량(mm)'], data['전체_건수']], labels=['rain', 'count'])
plt.title('Box Plot of Daily Rainfall and Rental Count')
plt.ylabel('Value')
plt.grid(True)
plt.show()

# %%
# 데이터의 'rainfall_amount'와 'rental_count'를 포함하는 long format 데이터 생성
data_long = pd.melt(data, id_vars=['기준_날짜'], value_vars=['일강수량(mm)', '전체_건수'],
                    var_name='Type', value_name='Value')

# 박스플롯 생성
plt.figure(figsize=(10, 6))
sns.boxplot(x='Type', y='Value', data=data_long)
plt.title('Box Plot of Daily Rainfall and Rental Count')
plt.xlabel('Type')
plt.ylabel('Value')
plt.grid(True)
plt.show()
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47049 (\N{HANGUL SYLLABLE RYANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
# 데이터의 'rainfall_amount'와 'rental_count'를 포함하는 long format 데이터 생성
data_long = pd.melt(data, id_vars=['기준_날짜'], value_vars=['일강수량(mm)', '전체_건수'],
                    var_name='Type', value_name='Value')

# 박스플롯 및 점 플롯 생성
plt.figure(figsize=(12, 8))
sns.boxplot(x='Type', y='Value', data=data_long, color='lightgray')  # 박스플롯
sns.swarmplot(x='Type', y='Value', data=data_long, color='blue')  # 점 플롯
plt.title('Box and Swarm Plot of Daily Rainfall and Rental Count')
plt.xlabel('Type')
plt.ylabel('Value')
plt.grid(True)
plt.show()
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   fig.canvas.draw()
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from current font.
#   fig.canvas.draw()
# ...

# %%
# 데이터의 'rainfall_amount'와 'rental_count'를 포함하는 long format 데이터 생성
data_long = pd.melt(data, id_vars=['기준_날짜'], value_vars=['평균기온(°C)', '전체_건수'],
                    var_name='Type', value_name='Value')

# 박스플롯 및 점 플롯 생성
plt.figure(figsize=(12, 8))
sns.boxplot(x='Type', y='Value', data=data_long, color='lightgray')  # 박스플롯
sns.swarmplot(x='Type', y='Value', data=data_long, color='blue')  # 점 플롯
plt.title('Box and Swarm Plot of Daily Rainfall and Rental Count')
plt.xlabel('Type')
plt.ylabel('Value')
plt.grid(True)
plt.show()
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from current font.
#   fig.canvas.draw()
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 44512 (\N{HANGUL SYLLABLE GYUN}) missing from current font.
#   fig.canvas.draw()
# ...

# %%
# 데이터의 'rainfall_amount'와 'rental_count'를 포함하는 long format 데이터 생성
data_long = pd.melt(data, id_vars=['기준_날짜'], value_vars=['미세먼지', '전체_건수'],
                    var_name='Type', value_name='Value')

# 박스플롯 및 점 플롯 생성
plt.figure(figsize=(12, 8))
sns.boxplot(x='Type', y='Value', data=data_long, color='lightgray')  # 박스플롯
sns.swarmplot(x='Type', y='Value', data=data_long, color='blue')  # 점 플롯
plt.title('Box and Swarm Plot of Daily Rainfall and Rental Count')
plt.xlabel('Type')
plt.ylabel('Value')
plt.grid(True)
plt.show()
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 48120 (\N{HANGUL SYLLABLE MI}) missing from current font.
#   fig.canvas.draw()
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 49464 (\N{HANGUL SYLLABLE SE}) missing from current font.
#   fig.canvas.draw()
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# CSV 파일 로드
rainfall = pd.read_csv('기온강수량미세먼지2.csv',encoding='cp949')  # 일별 강수량 데이터
rentals = pd.read_csv('일별따릉이.csv')  # 일별 따릉이 대여량 데이터

# 날짜 형식 통일 및 데이터 병합
rainfall['기준_날짜'] = pd.to_datetime(rainfall['기준_날짜'])
rentals['기준_날짜'] = pd.to_datetime(rentals['기준_날짜'])
data = pd.merge(rainfall, rentals, on='기준_날짜', how='inner')

# 강수량 및 대여량에 따라 데이터 그룹화 및 피봇
data['일강수량(mm)'] = pd.cut(data['일강수량(mm)'], bins=[0, 5, 10, 20, 50, 100], include_lowest=True, right=False)
data['전체_건수'] = pd.cut(data['전체_건수'], bins=[0, 1000, 2000, 3000, 4000, 5000, 10000], include_lowest=True, right=False)
pivot_table = data.pivot_table(index='일강수량(mm)', columns='전체_건수', values='기준_날짜', aggfunc='count', fill_value=0)

# %%
# 히트맵 생성
plt.figure(figsize=(12, 8))
sns.heatmap(pivot_table, annot=True, cmap='coolwarm', fmt='d')
plt.title('Heatmap of Daily Rainfall and Rental Count')
plt.xlabel('Daily Rental Count Ranges')
plt.ylabel('Daily Rainfall Ranges (mm)')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# CSV 파일 로드
rainfall = pd.read_csv('기온강수량미세먼지2.csv',encoding='cp949')  # 일별 강수량 데이터
rentals = pd.read_csv('일별따릉이.csv')  # 일별 따릉이 대여량 데이터

# 날짜 형식 통일 및 데이터 병합
rainfall['기준_날짜'] = pd.to_datetime(rainfall['기준_날짜'])
rentals['기준_날짜'] = pd.to_datetime(rentals['기준_날짜'])
data = pd.merge(rainfall, rentals, on='기준_날짜', how='inner')

# 강수량 및 대여량에 따라 데이터 그룹화 및 피봇
data['평균기온(°C)'] = pd.cut(data['평균기온(°C)'], bins=[ -20,-10, 0, 10, 20, 30, 40], include_lowest=True, right=False)
data['전체_건수'] = pd.cut(data['전체_건수'], bins=[0, 1000, 2000, 3000, 4000, 5000, 10000], include_lowest=True, right=False)
pivot_table = data.pivot_table(index='평균기온(°C)', columns='전체_건수', values='기준_날짜', aggfunc='count', fill_value=0)

# %%
# 히트맵 생성
plt.figure(figsize=(12, 8))
sns.heatmap(pivot_table, annot=True, cmap='coolwarm', fmt='d')
plt.title('Heatmap of Daily temperature and Rental Count')
plt.xlabel('Daily Rental Count Ranges')
plt.ylabel('Daily temperature')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# CSV 파일 로드
rainfall = pd.read_csv('기온강수량미세먼지2.csv',encoding='cp949')  # 일별 강수량 데이터
rentals = pd.read_csv('일별따릉이.csv')  # 일별 따릉이 대여량 데이터

# 날짜 형식 통일 및 데이터 병합
rainfall['기준_날짜'] = pd.to_datetime(rainfall['기준_날짜'])
rentals['기준_날짜'] = pd.to_datetime(rentals['기준_날짜'])
data = pd.merge(rainfall, rentals, on='기준_날짜', how='inner')

# 강수량 및 대여량에 따라 데이터 그룹화 및 피봇
data['미세먼지'] = pd.cut(data['미세먼지'], bins=[ -1,-15, 35, 75, float('inf')], include_lowest=True, right=False)
data['전체_건수'] = pd.cut(data['전체_건수'], bins=[0, 1000, 2000, 3000, 4000, 5000, 10000], include_lowest=True, right=False)
pivot_table = data.pivot_table(index='미세먼지', columns='전체_건수', values='기준_날짜', aggfunc='count', fill_value=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 15
#      12 data = pd.merge(rainfall, rentals, on='기준_날짜', how='inner')
#      14 # 강수량 및 대여량에 따라 데이터 그룹화 및 피봇
# ---> 15 data['미세먼지'] = pd.cut(data['미세먼지'], bins=[ -1,-15, 35, 75, float('inf')], include_lowest=True, right=False)
#      16 data['전체_건수'] = pd.cut(data['전체_건수'], bins=[0, 1000, 2000, 3000, 4000, 5000, 10000], include_lowest=True, right=False)
#      17 pivot_table = data.pivot_table(index='미세먼지', columns='전체_건수', values='기준_날짜', aggfunc='count', fill_value=0)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\reshape\tile.py:291, in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates, ordered)
#     289     # GH 26045: cast to float64 to avoid an overflow
#     290     if (np.diff(bins.astype("float64")) < 0).any():
# ...

# %%
# 히트맵 생성
plt.figure(figsize=(12, 8))
sns.heatmap(pivot_table, annot=True, cmap='coolwarm', fmt='d')
plt.title('Heatmap of Daily temperature and Rental Count')
plt.xlabel('Daily Rental Count Ranges')
plt.ylabel('Daily temperature')
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 18
#      15 merged_data = pd.merge(temp_data, bike_data, on='기준_날짜')
#      17 # 히트맵을 위한 피벗 테이블 생성
# ---> 18 heatmap_data = merged_data.pivot("기준_날짜", "평균기온(°C)", "전체_건수")  # 기온을 열로, 대여량을 값으로 사용
#      20 # 히트맵 그리기
#      21 plt.figure(figsize=(12, 8))
#
# TypeError: DataFrame.pivot() takes 1 positional argument but 4 were given

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 18
#      15 merged_data = pd.merge(temp_data, bike_data, on='기준_날짜')
#      17 # 히트맵을 위한 피벗 테이블 생성
# ---> 18 heatmap_data = merged_data.pivot(index="기준_날짜", columns="평균기온(°C)", values="전체_건수")  # 기온을 열로, 대여량을 값으로 사용
#      20 # 히트맵 그리기
#      21 plt.figure(figsize=(12, 8))
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:9025, in DataFrame.pivot(self, columns, index, values)
#    9018 @Substitution("")
#    9019 @Appender(_shared_docs["pivot"])
#    9020 def pivot(
#    9021     self, *, columns, index=lib.no_default, values=lib.no_default
#    9022 ) -> DataFrame:
#    9023     from pandas.core.reshape.pivot import pivot
# -> 9025     return pivot(self, index=index, columns=columns, values=values)
#
# ...
